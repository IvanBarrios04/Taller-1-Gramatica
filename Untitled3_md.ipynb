# %% [markdown]
# ---
# Nombre: Iván Andrés Barrios
# Fecha: 17/03/2024
# Materia: Gramática y lenguajes formales
# ---
#
# # Taller 1
#
# **1.**
#
# Representación tabular:
#
# |    | I     | q1    | q2    | q3    | F     |
# |----|-------|-------|-------|-------|-------|
# |**a**  | {q1}  | { }   | { }   | {F}   | {q1}  |
# |**b**  | {I}   | {q2}  | {q3}  | { }   | { }   |
#
# <br>
#
# Representación formal:
#
# Q: {I, q1, q2, q3, F}
#
# ∑: {a,b}
#
# δ: δ(I,a)q1 - δ(I,b)I - δ(q1,b)q2 - δ(q2,b)q3 - δ(q3,b)F - δ(F,a)q1
#
# q0: I
#
# F: {F}
#
# A = < Q, ∑, δ, q0, F >
#
# <br>
#
#
# A = md2mc('''
#
# DFA
#
# IF: a -> q1
#
# q1: b -> q2
#
# q2: b -> q3
#
# q3: b -> F
#
# F: a -> q1
#
# IF: b -> IF
#
# ''')
#
# dotObj_dfa(A,FuseEdges=True)
#
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>
#
# **2.**
#
# Representación tabular:
#
# |    | I     | q1    | q2    | F     |
# |----|-------|-------|-------|-------|
# |**0**  | {F}   | {q2}  | {F}   | {F}   |
# |**1** | {q1}  | {q1}  | {q1}  | {q1}  |
#
# <br>
#
# Representación formal:
#
# Q: {I,q1,q2,F}
#
# ∑: {0,1}
#
# δ: δ(I,0)F - δ(I,1)q1 - δ(q1,0)q2 - δ(q1,1)q1 - δ(q2,0)F - δ(q2,1)q1 - δ(F,0)F - δ(F,1)q1
#
# q0: I
#
# F: {F}
#
# A = {Q, ∑, δ, q0, F}
#
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>
#
# **3.**
# $\epsilon$: {I}
#
# b: {I, $q_1$}
#
# ba: {I, $q_2$, F}
#
# baa: {I, F, BH}
#
# <br>
# <br>
#
# **4.**
#
# Representacion tabular:
#
# |    | I      | q1     | q2     | F      |
# |----|--------|--------|--------|--------|
# |**a** | {I,q2} |  {q2,F}|  {F}   |  {}    |
# |**b**  | {I,q1} |  {}    | {}     |  {}    |
#
# <br>
#
# Representación formal:
#
# Q: {I, q1, q2, F}
#
# ∑: {a,b}
#
# δ: δ(I,a){I,q2}  -  δ(I,b){I,q1}  -  δ(q1,a){q2,F}  -  δ(q2,a){F}
#
# q0: I
#
# F: {F}
#
# A = < Q, ∑, δ, q0, F >
#
# <br>
# <br>
#
# **5.**
#
# C = md2mc('''
#
# DFA
#
# I: a -> q1I
#
# I: b -> I
#
# I: c -> q3I
#
# q1I: a -> q1I
#
# q1I: b -> Fq2I
#
# q1I: c -> q3I
#
# q3I: a -> q1I
#
# q3I: b -> I
#
# q3I: c -> Fq3q4I
#
# Fq2I: a -> q1I
#
# Fq2I: b -> I
#
# Fq2I: c -> q3I
#
# Fq3q4I: a -> q1I
#
# Fq3q4I: b -> I
#
# Fq3q4I: c -> Fq3q4I
#
# ''')
# dotObj_dfa(C,FuseEdges=True)
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>
#
# **6.**
#
# NFA:
#
# Representación tabular
#
#  | |I|q1|q3|Fq2|Fq4|
#  |-|-|-|-|-|-|
#  |a|{I,q1}|{ }|{ }|{ }|{ }|
#  |b|{I}|{Fq2}|{ }|{ }|{ }|
#  |c|{I,q3}|{ }|{Fq4 }|{ }|{ }|
#
#  <br>
#
# Representación formal
#
#  Q: {I,q1,q3,Fq2,Fq4}
#  ∑: {a,b,c}
#  δ: δ(I,a)I,q1 - δ(I,b)I - δ(I,c)I,q3 - δ(q1,b)Fq2 - δ(q3,c)Fq4
#  q0: I Estado inicial
#  F: F Estado de aceptación
#
#  A = {Q, ∑, δ, q0, F}
#
# <br>
# <br>
#
# DFA:
#
# Representación tabular:
#
# | |I|Iq1|Iq3|IFq2|Iq3Fq4|
#  |-|-|-|-|-|-|
#  |a|{Iq1}|{Iq1}|{Iq1}|{Iq1}|{Iq1}|
#  |b|{I}|{IFq2}|{I}|{I}|{I}|
#  |c|{Iq3}|{Iq3}|{Iq3Fq4}|{Iq3}|{Iq3Fq4}|
#
#
# <br>
#
# Representación formal:
#
# Q: {I,q1,q3,Fq2,Fq4}
#
# ∑: {a,b,c}
#
# δ: δ(I,a)Iq1 - δ(I,b)I - δ(I,c)Iq3 - δ: δ(Iq1,a)Iq1 - δ(Iq1,b)IFq2 - δ(Iq1,c)Iq3 - δ(Iq3,a)I,q1 - δ(Iq3,b)I - δ(Iq3,c)Iq3Fq4 - δ: δ(IFq2,a)Iq1 - δ(IFq2,b)I - δ(IFq2,c)Iq3 - δ: δ(IFq4,a)Iq1 - δ(IFq4,b)I - δ(IFq4,c)Iq3Fq4
#
# q0: I
#
# F: {Fq4}
#
# A = {Q, ∑, δ, q0, F}
#
# <br>
# <br>
#
# **7.**
#
# Dados L y M, dos lenguajes regulares:
#
# Como L es LR existe un DFA A= (Qa, Σ, δa, Ia, Fa) tal que L = L(A)
#
# Como M es LR existe un DFA B= (Qb, Σ, δb, Ib, Fb) tal que M = M(B)
#
# A partir de A y B es posible definir un NFA C = (Q, Σ, δ, I, F) tal que L(C) = L(A) ∪ L(B) = L ∪ M
#
# El automata C se define de la siguiente manera:
# Q = Qa ∪ Qb ∪ I
# Σ = Σ
# Q0 = I
# F = Fa ∪ Fb
#
# δ: Q x Σ → Q se define como:
#
# δ(qn, w) = {
#             δa(qn, w) si qn ∈ Qa
#             δb(qn, w) si qn ∈ Qb
#             {(I,ε,{IA, Ib})}
#            }
#
# para todo qn ∈ Qa ∪ Qb ∪ I y para todo w ∈ Σ
#
# Como L(C) = L(A) ∪ M(B) = L ∪ M, entonces L ∪ M es un lenguaje regular.
#
# <br>
# <br>
#
# **8.**
#
# Dados L y M, dos lenguajes regulares:
#
# Como L es LR existe un DFA A= (Qa, Σ, δa, Ia, Fa) tal que L = L(A)
#
# Como M es LR existe un DFA B= (Qb, Σ, δb, Ib, Fb) tal que M = M(B)
#
# A partir de A y B es posible definir un NFA C = (Q, Σ, δ, I, F) tal que L(C) = L(A) ∩ L(B) = L ∩ M
#
# El automata C se define de la siguiente manera:
# Q = Qa ∪ Qb ∪ I
# Σ = Σ
# Q0 = I
# F = Fa ∩ Fb
#
# δ: Q x Σ → Q se define como:
#
# δ(qn, w) = {
#             δa(qn, w) si qn ∈ Qa
#             δb(qn, w) si qn ∈ Qb
#             {(I,ε,{IA, Ib})}
#            }
#
# para todo qn ∈ Qa ∪ Qb ∪ I y para todo w ∈ Σ
#
# Como L(C) = L(A) ∩ M(B) = L ∩ M, entonces L ∩ M es un lenguaje regular.
#
# Este automata resulta en un NFA, en cuyo caso se puede convertir a un DFA
#
#
# <br>
# <br>
#
# **9.**
#
#
# Dados L y M, dos lenguajes regulares:
#
# Como L es LR existe un DFA A= (Qa, Σ, δa, Ia, Fa) tal que L = L(A)
#
# Como M es LR existe un DFA B= (Qb, Σ, δb, Ib, Fb) tal que M = M(B)
#
# A partir de A y B es posible definir un DFA C = (Q, Σ, δ, I, F) tal que L(C) = L(A) * L(B) = L * M
#
# El automata C se define de la siguiente manera:
# Q = Qa ∪ Qb ∪ I
# Σ = Σ
# Q0 = I
# F = Fa ∪ Fb
#
# se crea un estado inicial I = Ia ∪ Ib
# δ: Q x Σ → Q se define como:
#
# δ(qn, w) = {
#             δa(qn, w) si qn ∈ Qa
#             δb(qn, w) si qn ∈ Qb
#             {(I,ε,{IA, Ib})}
#            }
#
# para todo qn ∈ Qa ∪ Qb y para todo w ∈ Σ
#
# Como L(C) = L(A) * M(B) = L * M, entonces L * M es un lenguaje regular.
#
# Este automata resulta en un NFA, en cuyo caso se puede convertir a un DFA
#
# <br>
# <br>
#
# **10.**
#
# Dado L, un lenguaje regular:
#
# Como L es LR existe un DFA A= (Qa, Σ, δa, Ia, Fa) tal que L = L(A)
#
# A partir de A es posible definir un FA B = (Q, Σ, δ, I, F) tal que RL(B) = L(A)
#
# El automata B se define de la siguiente manera:
# Q = Qa
# Σ = Σ
# Q0 = Fa
# F = Ia
#
# δ: Q x Σ → Q donde las transiciones van en dirección contraria a las de δa
#
# Este automata puede resultar en un NFA, en cuyo caso se puede convertir a un DFA
#
# <br>
# <br>
#
# **11.**
#
# <br>
# <br>
#
# **12.**
#
# <br>
# <br>
#
# **13.**
#
# <br>
# <br>
#
# **14.**
#
# <br>
# <br>
#
# **15.**
#
# {11 , 0101}
#
# <br>
# <br>
#
# **16.**
#
# Representación tabular:
#
# |    | I     | Fq1    | q2    | q3     |
# |----|-------|-------|-------|-------|
# |**a** | {Fq1} | {Fq1} | {Fq1} | {q3}   |
# |**b** | {q3}  | {q2}  | {q2}  | {q3}  |
# |**c** | {q3}  | {q3}  | {q3}  | {q3}  |
#
# <br>
#
# Representación formal:
#
# Q: {I,Fq1,q2,q3}
#
# ∑: {a,b,c}
#
# δ: δ(I,a)Fq1 - δ(I,b)q3 - δ(I,c)q3 - δ(Fq1,a)Fq1 - δ(Fq1,b)q2 - δ(Fq1,c)q2 - δ(q2,a)Fq1 - δ(q2,b)q2 - δ(q2,c)q3 - δ(q3,a)q3 - δ(q3,b)q3 - δ(q3,c)q3
#
# q0: I
#
# F: {Fq1}
#
# A = {Q, ∑, δ, q0, F}
#
#
# <br>
# <br>
#
# **17.**
# C = md2mc('''
#
# DFA
#
# I: 0 -> q1
#
# q1: x -> q2
#
# q2: 1 -> Fq3
#
# Fq3: 0 -> Fq3
#
# Fq3: x -> Fq3
#
# Fq3: 1 -> Fq3
#
# ''')
#
# dotObj_dfa(C,FuseEdges=True)
#
#
# ![image.png](data:image/png;base64,...)
#
# **18.**
# C = md2mc('''
#
# DFA
#
# I: 0 -> q1
#
# I: 1 -> q2
#
# q1: 1 -> q3
#
# q2: 0 -> q8
#
# q2: 1 -> Fq7
#
# q3: 0 -> Fq4
#
# q3: 1 -> q5
#
# q5: 0 -> FQ6
#
# q8: 1 -> FQ9
#
# ''')
#
# dotObj_dfa(C,FuseEdges=True)
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>
#
#
# **19.**
#
# Representación tabular:
#
# |    | I     | Fq1    | Fq2    | Fq3    | Fq4    |
# |----|-------|--------|--------|--------|--------|
# |**0**  | {I}   |{Fq1}   |{Fq2 }  |{Fq3}   |{Fq4}   |
# |**1**  | {Fq1} |{Fq2}   |{Fq3}   |{Fq4}   |{I}     |
#
# <br>
#
# Representación formal:
#
# Q: {I, Fq1, Fq2, Fq3, Fq4}
#
# ∑: {0,1}
#
# δ: δ(I,0)I - δ(I,1)Fq1 - δ(Fq1,0)Fq1 - δ(Fq1,1)Fq2 - δ(Fq2,0)Fq2 - δ(Fq2,1)Fq3 - δ(Fq3,0)Fq3 - δ(Fq3,1)Fq4 - δ(Fq4,0)Fq4 - δ(Fq4,1)I
#
# q0: I
#
# F: {Fq1,Fq2,Fq3,Fq4}
#
# A = < Q, ∑, δ, q0, F >
#
#
# C = md2mc('''
#
# DFA
#
# I: 1 -> Fq1
#
# I: 0 -> I
#
# Fq1: 1 -> Fq2
#
# Fq1: 0 -> Fq1
#
# Fq2: 1 -> Fq3
#
# Fq2: 0 -> Fq2
#
# Fq3: 1 -> Fq4
#
# Fq3: 0 -> Fq3
#
# Fq4: 1 -> I
#
# Fq4: 0 -> Fq4
#
#
# ''')
#
# ![image.png](data:image/png;base64,...)
#
# dotObj_dfa(C,FuseEdges=True)
#
# <br>
# <br>
#
# **20.**
# C = md2mc('''
#
# NFA
#
# I: 1 -> I
#
# I: 0 -> I
#
# I: 1 -> q1
#
# q1: 0 -> q2
#
# q2: 1 -> Fq3
#
# Fq3: 0 -> Fq3
#
# Fq3: 1 -> Fq3
#
# ''')
#
# dotObj_nfa(C,FuseEdges=True)
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>
#
# **21.**
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>
#
# **22.**
#
# C = md2mc('''
#
# DFA
#
# I: 0 -> I
#
# I: 1 -> q1I
#
# q1I: 0 -> q2I
#
# q1I: 1 -> q1IBH
#
# q2I: 0 -> BHI
#
# q2I: 1 -> Fq3Iq1
#
# q1IBH: 0 -> q2IBH
#
# q1IBH: 1 -> q1IBH
#
# BHI: 0 ->  BHI
#
# BHI: 1 -> q1IBH
#
# Fq3Iq1: 0 -> Fq3Iq2
#
# Fq3Iq1: 1 -> Fq3Iq1BH
#
# q2IBH: 0 -> BHI
#
# q2IBH: 1 -> Fq3Iq1BH
#
# Fq3Iq2: 0 -> Fq3IBH
#
# Fq3Iq2: 1 -> Fq3Iq1
#
# Fq3Iq1BH: 0 -> Fq3Iq2BH
#
# Fq3Iq1BH: 1 -> Fq3Iq1BH
#
# Fq3IBH: 0 -> Fq3IBH
#
# Fq3IBH: 1 -> Fq3Iq1BH
#
# Fq3Iq2BH: 0 -> Fq3IBH
#
# Fq3Iq2BH: 1 -> Fq3Iq1BH
#
# ''')
#
# dotObj_dfa(C,FuseEdges=True)
#
# ![image.png](data:image/png;base64,...)
#
#
# <br>
# <br>
#
# **23.**
#
# <br>
# <br>
#
# **24.**
#
# <br>
# <br>
#
# **25.**
# C = md2mc('''
#
# DFA
#
# I: 1 -> I
#
# I: 0 -> q1I
#
# q1I: 0 -> q1IBH
#
# q1I: 1 -> Fq2I
#
# q1IBH: 0 -> q1IBH
#
# q1IBH: 1 -> Fq2IBH
#
# Fq2IBH: 0 -> q1IBH
#
# Fq2IBH: 1 -> BHI
#
# BHI: 1 -> BHI
#
# BHI: 0 -> q1IBH
#
# Fq2I: 0 -> q1IBH
#
# Fq2I: 1 -> BHI
#
# ''')
#
# dotObj_dfa(C,FuseEdges=True)
#
# ![Captura de pantalla 2024-03-17 114250.png](data:image/png;base64,...)
#
# <br>
# <br>
#
# **26.**
# L = {}
#
# <br>
# <br>
#
# **27.**
# L = {$\epsilon$}
